# %% [markdown]
# ✅ 1. Setup: Prioritize Local src/ Directory for Imports

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../src"))

from model_eval import evaluate_model
from resampling import (
    manual_upsampling, smote, adasyn, borderline_smote,
    smote_tomek, smote_enn, random_undersample, cluster_centroids
)

# %% [markdown]
# ✅ 2. Define Resamplers

# %%
# 📦 Standard setup: load, split, and prep data
from preprocessing import load_and_prepare_data, split_and_scale, select_top_features

# 📂 Path to your dataset
data_path = "../data/synth_rare_event_data.csv"
target_col = "rare_event"

# 🧼 Load and prepare
X, y = load_and_prepare_data(data_path, target_col)
X_train_scaled, X_test_scaled, y_train, y_test = split_and_scale(X, y)
X_train, X_test, _ = select_top_features(X_train_scaled, y_train, X_test_scaled, return_features=True)

# %%
# 📊 Define resampling strategies
resamplers = {
    "Manual Upsampling": lambda: manual_upsampling(X_train, y_train, target_col),
    "SMOTE": lambda: smote(X_train, y_train),
    "ADASYN": lambda: adasyn(X_train, y_train),
    "Borderline SMOTE": lambda: borderline_smote(X_train, y_train),
    "SMOTETomek": lambda: smote_tomek(X_train, y_train),
    "SMOTEENN": lambda: smote_enn(X_train, y_train),
    "Random Undersample": lambda: random_undersample(X_train, y_train),
    "Cluster Centroids": lambda: cluster_centroids(X_train, y_train),
    "No Resampling": lambda: (X_train, y_train)
}

# %%
resampled_datasets = {
    name: fn() for name, fn in resamplers.items()
}

population = breed_and_battle(
    resampled_datasets=resampled_datasets,
    X_test=X_test,
    y_test=y_test,
    generations=3,
    top_k=3
)
# Out:
# --- Manual Upsampling ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.72      1000
#
# ROC AUC: 0.653
# PR AUC: 0.035
# 👊 Manual Upsampling enters the arena!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.035
#
# --- SMOTE ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.632
# PR AUC: 0.029
# 👊 SMOTE enters the arena!
# 📍 Style: SMOTE
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.029
#
# --- ADASYN ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.58      0.73       982
#            1       0.02      0.50      0.04        18
#
#     accuracy                           0.58      1000
#    macro avg       0.50      0.54      0.39      1000
# weighted avg       0.97      0.58      0.72      1000
#
# ROC AUC: 0.617
# PR AUC: 0.03
# 👊 ADASYN enters the arena!
# 📍 Style: ADASYN
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.030
#
# --- Borderline SMOTE ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.68      0.80       982
#            1       0.02      0.44      0.05        18
#
#     accuracy                           0.67      1000
#    macro avg       0.50      0.56      0.42      1000
# weighted avg       0.97      0.67      0.79      1000
#
# ROC AUC: 0.579
# PR AUC: 0.026
# 👊 Borderline SMOTE enters the arena!
# 📍 Style: Borderline SMOTE
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.026
#
# --- SMOTETomek ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.632
# PR AUC: 0.029
# 👊 SMOTETomek enters the arena!
# 📍 Style: SMOTETomek
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.029
#
# --- SMOTEENN ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.57      0.73       982
#            1       0.03      0.67      0.05        18
#
#     accuracy                           0.57      1000
#    macro avg       0.51      0.62      0.39      1000
# weighted avg       0.97      0.57      0.71      1000
#
# ROC AUC: 0.619
# PR AUC: 0.027
# 👊 SMOTEENN enters the arena!
# 📍 Style: SMOTEENN
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.027
#
# --- Random Undersample ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.53      0.69       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.54      1000
#    macro avg       0.50      0.55      0.37      1000
# weighted avg       0.97      0.54      0.68      1000
#
# ROC AUC: 0.606
# PR AUC: 0.032
# 👊 Random Undersample enters the arena!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.032
#
# --- Cluster Centroids ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.043
# 👊 Cluster Centroids enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.043
#
# --- No Resampling ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.47      0.63       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.47      1000
#    macro avg       0.50      0.51      0.33      1000
# weighted avg       0.97      0.47      0.62      1000
#
# ROC AUC: 0.529
# PR AUC: 0.023
# /Users/sophiaboettcher/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 👊 No Resampling enters the arena!
# 📍 Style: No Resampling
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.023
#
# 🎮 Generation 1 Begins!
# ------------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids: PR AUC = 0.043
# 2. Manual Upsampling: PR AUC = 0.035
# 3. Random Undersample: PR AUC = 0.032
#
# 💘 Breeding Pairs:
# - Cluster Centroids breeds 2 children
#
# --- Cluster Centroids_child_1_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.042
# 👊 Cluster Centroids_child_1_G1 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.48
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids (Gen 0)
#
# --- Cluster Centroids_child_2_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.043
# 👊 Cluster Centroids_child_2_G1 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.09, l1_ratio = 0.54
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids (Gen 0)
# - Manual Upsampling breeds 2 children
#
# --- Manual Upsampling_child_1_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.72      1000
#
# ROC AUC: 0.653
# PR AUC: 0.035
# 👊 Manual Upsampling_child_1_G1 enters the arena!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 1.06, l1_ratio = 0.56
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.035
# 🧬 Lineage: child of Manual Upsampling (Gen 0)
#
# --- Manual Upsampling_child_2_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.72      1000
#
# ROC AUC: 0.653
# PR AUC: 0.035
# 👊 Manual Upsampling_child_2_G1 enters the arena!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 1.03, l1_ratio = 0.55
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.035
# 🧬 Lineage: child of Manual Upsampling (Gen 0)
# - Random Undersample breeds 2 children
#
# --- Random Undersample_child_1_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.53      0.69       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.53      1000
#    macro avg       0.50      0.54      0.37      1000
# weighted avg       0.97      0.53      0.68      1000
#
# ROC AUC: 0.606
# PR AUC: 0.032
# 👊 Random Undersample_child_1_G1 enters the arena!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.07, l1_ratio = 0.56
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.032
# 🧬 Lineage: child of Random Undersample (Gen 0)
#
# --- Random Undersample_child_2_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.54      0.70       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.54      1000
#    macro avg       0.50      0.55      0.37      1000
# weighted avg       0.97      0.54      0.68      1000
#
# ROC AUC: 0.604
# PR AUC: 0.032
# 👊 Random Undersample_child_2_G1 enters the arena!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 0.90, l1_ratio = 0.55
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.032
# 🧬 Lineage: child of Random Undersample (Gen 0)
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_child_2_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.043
# - Cluster Centroids (Cluster Centroids) | Gen 0 | PR AUC = 0.043
# - Cluster Centroids_child_1_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.042
# - Manual Upsampling (Manual Upsampling) | Gen 0 | PR AUC = 0.035
# - Manual Upsampling_child_1_G1 (Manual Upsampling) | Gen 1 | PR AUC = 0.035
# - Manual Upsampling_child_2_G1 (Manual Upsampling) | Gen 1 | PR AUC = 0.035
# - Random Undersample_child_1_G1 (Random Undersample) | Gen 1 | PR AUC = 0.032
# - Random Undersample_child_2_G1 (Random Undersample) | Gen 1 | PR AUC = 0.032
# - Random Undersample (Random Undersample) | Gen 0 | PR AUC = 0.032
#
# 🎮 Generation 2 Begins!
# ------------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_child_2_G1: PR AUC = 0.043
# 2. Cluster Centroids: PR AUC = 0.043
# 3. Cluster Centroids_child_1_G1: PR AUC = 0.042
#
# 💘 Breeding Pairs:
# - Cluster Centroids_child_2_G1 breeds 2 children
#
# --- Cluster Centroids_child_1_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.043
# 👊 Cluster Centroids_child_1_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.15, l1_ratio = 0.60
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_child_2_G1 (Gen 1)
#
# --- Cluster Centroids_child_2_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.04
# 👊 Cluster Centroids_child_2_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.07, l1_ratio = 0.58
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_child_2_G1 (Gen 1)
# - Cluster Centroids breeds 2 children
#
# --- Cluster Centroids_child_1_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.04
# 👊 Cluster Centroids_child_1_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.99, l1_ratio = 0.54
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids (Gen 1)
#
# --- Cluster Centroids_child_2_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.64
# PR AUC: 0.042
# 👊 Cluster Centroids_child_2_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.07, l1_ratio = 0.43
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids (Gen 1)
# - Cluster Centroids_child_1_G1 breeds 2 children
#
# --- Cluster Centroids_child_1_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.04
# 👊 Cluster Centroids_child_1_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.94, l1_ratio = 0.51
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_child_1_G1 (Gen 1)
#
# --- Cluster Centroids_child_2_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.04
# 👊 Cluster Centroids_child_2_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.94, l1_ratio = 0.56
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_child_1_G1 (Gen 1)
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_2_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.043
# - Cluster Centroids (Cluster Centroids) | Gen 0 | PR AUC = 0.043
# - Cluster Centroids_child_1_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.042
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.042
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.040
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.040
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.040
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.040
#
# 🎮 Generation 3 Begins!
# ------------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_child_1_G2: PR AUC = 0.043
# 2. Cluster Centroids_child_2_G1: PR AUC = 0.043
# 3. Cluster Centroids: PR AUC = 0.043
#
# 💘 Breeding Pairs:
# - Cluster Centroids_child_1_G2 breeds 2 children
#
# --- Cluster Centroids_child_1_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.042
# 👊 Cluster Centroids_child_1_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.13, l1_ratio = 0.54
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_child_1_G2 (Gen 2)
#
# --- Cluster Centroids_child_2_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.043
# 👊 Cluster Centroids_child_2_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.21, l1_ratio = 0.61
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_child_1_G2 (Gen 2)
# - Cluster Centroids_child_2_G1 breeds 2 children
#
# --- Cluster Centroids_child_1_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.042
# 👊 Cluster Centroids_child_1_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.19, l1_ratio = 0.56
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_child_2_G1 (Gen 2)
#
# --- Cluster Centroids_child_2_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.042
# 👊 Cluster Centroids_child_2_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.16, l1_ratio = 0.57
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_child_2_G1 (Gen 2)
# - Cluster Centroids breeds 2 children
#
# --- Cluster Centroids_child_1_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.041
# 👊 Cluster Centroids_child_1_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.51
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids (Gen 2)
#
# --- Cluster Centroids_child_2_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.041
# 👊 Cluster Centroids_child_2_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.51
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids (Gen 2)
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_2_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.043
# - Cluster Centroids_child_2_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.043
# - Cluster Centroids (Cluster Centroids) | Gen 0 | PR AUC = 0.043
# - Cluster Centroids_child_2_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.042
# - Cluster Centroids_child_1_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.042
# - Cluster Centroids_child_1_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.042
# - Cluster Centroids_child_1_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.042
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.042

# %% [markdown]
# ✅ 3. Copy-Paste This Cell: Breed and Battle Implementation

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import random

def make_child_model(params):
    return LogisticRegression(
        penalty='elasticnet',
        solver='saga',
        l1_ratio=params["l1_ratio"],
        C=params["C"],
        max_iter=2000,
        tol=1e-4,
        class_weight='balanced',
        random_state=42
    )

def mutate_params(base_params, noise=0.1):
    return {
        "C": max(0.01, base_params["C"] + np.random.uniform(-noise, noise)),
        "l1_ratio": min(1.0, max(0.0, base_params["l1_ratio"] + np.random.uniform(-noise, noise)))
    }

def print_fighter_intro(f):
    print(f"\n👊 {f['label']} enters the arena!")
    print(f"📍 Style: {f['resampling']}")
    print(f"🧬 Genome: C = {f['params']['C']:.2f}, l1_ratio = {f['params']['l1_ratio']:.2f}")
    print(f"🔁 Generation: {f['generation']}")
    print(f"🏆 Last Score: PR AUC = {f['score']['pr_auc']:.3f}")
    if 'parent' in f:
        print(f"🧬 Lineage: child of {f['parent']} (Gen {f['generation'] - 1})")

def breed_and_battle(resampled_datasets, X_test, y_test, generations=3, top_k=3):
    population = []
    gen = 0

    # Generation 0: Initial fighters
    for label, (X_res, y_res) in resampled_datasets.items():
        base_params = {"C": 1.0, "l1_ratio": 0.5}
        model = make_child_model(base_params)
        model.fit(X_res, y_res)
        score = evaluate_model(model, X_test, y_test, label=label, return_scores=True)

        fighter = {
            "model": model,
            "params": base_params,
            "score": score,
            "label": label,
            "generation": gen,
            "resampling": label
        }
        print_fighter_intro(fighter)
        population.append(fighter)

    for gen in range(1, generations + 1):
        print(f"\n🎮 Generation {gen} Begins!\n{'-'*30}")
        population = sorted(population, key=lambda x: x["score"]["pr_auc"], reverse=True)
        top_fighters = population[:top_k]

        print(f"🏆 Top Performers:")
        for i, f in enumerate(top_fighters, 1):
            print(f"{i}. {f['label']}: PR AUC = {f['score']['pr_auc']:.3f}")

        new_fighters = []
        print(f"\n💘 Breeding Pairs:")
        for fighter in top_fighters:
            print(f"- {fighter['label']} breeds 2 children")
            for i in range(2):
                child_params = mutate_params(fighter["params"])
                model = make_child_model(child_params)
                X_res, y_res = resampled_datasets[fighter["resampling"]]
                model.fit(X_res, y_res)
                label = f"{fighter['resampling']}_child_{i+1}_G{gen}"
                score = evaluate_model(model, X_test, y_test, label=label, return_scores=True)
                child = {
                    "model": model,
                    "params": child_params,
                    "score": score,
                    "label": label,
                    "generation": gen,
                    "resampling": fighter["resampling"],
                    "parent": fighter["label"]
                }
                print_fighter_intro(child)
                new_fighters.append(child)

        all_fighters = population + new_fighters
        all_fighters = sorted(all_fighters, key=lambda x: x["score"]["pr_auc"], reverse=True)

        population = all_fighters[:len(resampled_datasets)]  # Survivor cap = original size

        print(f"\n✅ Survivors advancing to next generation:")
        for f in population:
            print(f"- {f['label']} ({f['resampling']}) | Gen {f['generation']} | PR AUC = {f['score']['pr_auc']:.3f}")

    return population

# %% [markdown]
# ✅ 4. Run It

# %%
resampled_datasets = {
    name: fn() for name, fn in resamplers.items()
}

population = breed_and_battle(
    resampled_datasets=resampled_datasets,
    X_test=X_test,
    y_test=y_test,
    generations=3,
    top_k=3
)
# Out:
# --- Manual Upsampling ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.72      1000
#
# ROC AUC: 0.653
# PR AUC: 0.035
# 👊 Manual Upsampling enters the arena!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.035
#
# --- SMOTE ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.632
# PR AUC: 0.029
# 👊 SMOTE enters the arena!
# 📍 Style: SMOTE
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.029
#
# --- ADASYN ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.58      0.73       982
#            1       0.02      0.50      0.04        18
#
#     accuracy                           0.58      1000
#    macro avg       0.50      0.54      0.39      1000
# weighted avg       0.97      0.58      0.72      1000
#
# ROC AUC: 0.617
# PR AUC: 0.03
# 👊 ADASYN enters the arena!
# 📍 Style: ADASYN
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.030
#
# --- Borderline SMOTE ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.68      0.80       982
#            1       0.02      0.44      0.05        18
#
#     accuracy                           0.67      1000
#    macro avg       0.50      0.56      0.42      1000
# weighted avg       0.97      0.67      0.79      1000
#
# ROC AUC: 0.579
# PR AUC: 0.026
# 👊 Borderline SMOTE enters the arena!
# 📍 Style: Borderline SMOTE
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.026
#
# --- SMOTETomek ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.632
# PR AUC: 0.029
# 👊 SMOTETomek enters the arena!
# 📍 Style: SMOTETomek
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.029
#
# --- SMOTEENN ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.57      0.73       982
#            1       0.03      0.67      0.05        18
#
#     accuracy                           0.57      1000
#    macro avg       0.51      0.62      0.39      1000
# weighted avg       0.97      0.57      0.71      1000
#
# ROC AUC: 0.619
# PR AUC: 0.027
# 👊 SMOTEENN enters the arena!
# 📍 Style: SMOTEENN
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.027
#
# --- Random Undersample ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.53      0.69       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.54      1000
#    macro avg       0.50      0.55      0.37      1000
# weighted avg       0.97      0.54      0.68      1000
#
# ROC AUC: 0.606
# PR AUC: 0.032
# 👊 Random Undersample enters the arena!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.032
#
# --- Cluster Centroids ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.043
# 👊 Cluster Centroids enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.043
#
# --- No Resampling ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.47      0.63       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.47      1000
#    macro avg       0.50      0.51      0.33      1000
# weighted avg       0.97      0.47      0.62      1000
#
# ROC AUC: 0.529
# PR AUC: 0.023
# /Users/sophiaboettcher/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 👊 No Resampling enters the arena!
# 📍 Style: No Resampling
# 🧬 Genome: C = 1.00, l1_ratio = 0.50
# 🔁 Generation: 0
# 🏆 Last Score: PR AUC = 0.023
#
# 🎮 Generation 1 Begins!
# ------------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids: PR AUC = 0.043
# 2. Manual Upsampling: PR AUC = 0.035
# 3. Random Undersample: PR AUC = 0.032
#
# 💘 Breeding Pairs:
# - Cluster Centroids breeds 2 children
#
# --- Cluster Centroids_child_1_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.043
# 👊 Cluster Centroids_child_1_G1 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.09, l1_ratio = 0.49
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids (Gen 0)
#
# --- Cluster Centroids_child_2_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.039
# 👊 Cluster Centroids_child_2_G1 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.57
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids (Gen 0)
# - Manual Upsampling breeds 2 children
#
# --- Manual Upsampling_child_1_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.72      1000
#
# ROC AUC: 0.653
# PR AUC: 0.035
# 👊 Manual Upsampling_child_1_G1 enters the arena!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 1.00, l1_ratio = 0.43
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.035
# 🧬 Lineage: child of Manual Upsampling (Gen 0)
#
# --- Manual Upsampling_child_2_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.03      0.61      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.60      0.39      1000
# weighted avg       0.97      0.59      0.72      1000
#
# ROC AUC: 0.653
# PR AUC: 0.035
# 👊 Manual Upsampling_child_2_G1 enters the arena!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 0.99, l1_ratio = 0.42
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.035
# 🧬 Lineage: child of Manual Upsampling (Gen 0)
# - Random Undersample breeds 2 children
#
# --- Random Undersample_child_1_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.98      0.53      0.69       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.53      1000
#    macro avg       0.50      0.54      0.37      1000
# weighted avg       0.97      0.53      0.68      1000
#
# ROC AUC: 0.606
# PR AUC: 0.032
# 👊 Random Undersample_child_1_G1 enters the arena!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.06, l1_ratio = 0.56
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.032
# 🧬 Lineage: child of Random Undersample (Gen 0)
#
# --- Random Undersample_child_2_G1 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.54      0.69       982
#            1       0.02      0.56      0.04        18
#
#     accuracy                           0.54      1000
#    macro avg       0.50      0.55      0.37      1000
# weighted avg       0.97      0.54      0.68      1000
#
# ROC AUC: 0.606
# PR AUC: 0.031
# 👊 Random Undersample_child_2_G1 enters the arena!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.01, l1_ratio = 0.41
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.031
# 🧬 Lineage: child of Random Undersample (Gen 0)
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_child_1_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.043
# - Cluster Centroids (Cluster Centroids) | Gen 0 | PR AUC = 0.043
# - Cluster Centroids_child_2_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.039
# - Manual Upsampling (Manual Upsampling) | Gen 0 | PR AUC = 0.035
# - Manual Upsampling_child_1_G1 (Manual Upsampling) | Gen 1 | PR AUC = 0.035
# - Manual Upsampling_child_2_G1 (Manual Upsampling) | Gen 1 | PR AUC = 0.035
# - Random Undersample_child_1_G1 (Random Undersample) | Gen 1 | PR AUC = 0.032
# - Random Undersample (Random Undersample) | Gen 0 | PR AUC = 0.032
# - Random Undersample_child_2_G1 (Random Undersample) | Gen 1 | PR AUC = 0.031
#
# 🎮 Generation 2 Begins!
# ------------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_child_1_G1: PR AUC = 0.043
# 2. Cluster Centroids: PR AUC = 0.043
# 3. Cluster Centroids_child_2_G1: PR AUC = 0.039
#
# 💘 Breeding Pairs:
# - Cluster Centroids_child_1_G1 breeds 2 children
#
# --- Cluster Centroids_child_1_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.043
# 👊 Cluster Centroids_child_1_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.16, l1_ratio = 0.50
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_child_1_G1 (Gen 1)
#
# --- Cluster Centroids_child_2_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.64
# PR AUC: 0.043
# 👊 Cluster Centroids_child_2_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.11, l1_ratio = 0.46
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_child_1_G1 (Gen 1)
# - Cluster Centroids breeds 2 children
#
# --- Cluster Centroids_child_1_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.04
# 👊 Cluster Centroids_child_1_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.51
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids (Gen 1)
#
# --- Cluster Centroids_child_2_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.64
# PR AUC: 0.042
# 👊 Cluster Centroids_child_2_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.10, l1_ratio = 0.40
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids (Gen 1)
# - Cluster Centroids_child_2_G1 breeds 2 children
#
# --- Cluster Centroids_child_1_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.043
# 👊 Cluster Centroids_child_1_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.98, l1_ratio = 0.51
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_child_2_G1 (Gen 1)
#
# --- Cluster Centroids_child_2_G2 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.637
# PR AUC: 0.04
# 👊 Cluster Centroids_child_2_G2 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.66
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_child_2_G1 (Gen 1)
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_1_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.043
# - Cluster Centroids (Cluster Centroids) | Gen 0 | PR AUC = 0.043
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.042
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.040
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.040
# - Cluster Centroids_child_2_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.039
#
# 🎮 Generation 3 Begins!
# ------------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_child_1_G2: PR AUC = 0.043
# 2. Cluster Centroids_child_1_G1: PR AUC = 0.043
# 3. Cluster Centroids: PR AUC = 0.043
#
# 💘 Breeding Pairs:
# - Cluster Centroids_child_1_G2 breeds 2 children
#
# --- Cluster Centroids_child_1_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.04
# 👊 Cluster Centroids_child_1_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.05, l1_ratio = 0.57
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_child_1_G2 (Gen 2)
#
# --- Cluster Centroids_child_2_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.64
# PR AUC: 0.043
# 👊 Cluster Centroids_child_2_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.07, l1_ratio = 0.45
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_child_1_G2 (Gen 2)
# - Cluster Centroids_child_1_G1 breeds 2 children
#
# --- Cluster Centroids_child_1_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.64
# PR AUC: 0.042
# 👊 Cluster Centroids_child_1_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.40
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_child_1_G1 (Gen 2)
#
# --- Cluster Centroids_child_2_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.041
# 👊 Cluster Centroids_child_2_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.58
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids_child_1_G1 (Gen 2)
# - Cluster Centroids breeds 2 children
#
# --- Cluster Centroids_child_1_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.638
# PR AUC: 0.039
# 👊 Cluster Centroids_child_1_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.53
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids (Gen 2)
#
# --- Cluster Centroids_child_2_G3 ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       982
#            1       0.02      0.56      0.05        18
#
#     accuracy                           0.59      1000
#    macro avg       0.51      0.57      0.39      1000
# weighted avg       0.97      0.59      0.73      1000
#
# ROC AUC: 0.639
# PR AUC: 0.042
# 👊 Cluster Centroids_child_2_G3 enters the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.07, l1_ratio = 0.48
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids (Gen 2)
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_1_G1 (Cluster Centroids) | Gen 1 | PR AUC = 0.043
# - Cluster Centroids_child_2_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.043
# - Cluster Centroids (Cluster Centroids) | Gen 0 | PR AUC = 0.043
# - Cluster Centroids_child_1_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.043
# - Cluster Centroids_child_2_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.042
# - Cluster Centroids_child_1_G3 (Cluster Centroids) | Gen 3 | PR AUC = 0.042
# - Cluster Centroids_child_2_G2 (Cluster Centroids) | Gen 2 | PR AUC = 0.042
