# %%
import sys, os
sys.path.insert(0, os.path.abspath("../src"))

from model_eval import evaluate_model
from resampling import (
    manual_upsampling, smote, adasyn, borderline_smote,
    smote_tomek, smote_enn, random_undersample, cluster_centroids
)

# %%
# 📦 Standard setup: load, split, and prep data
from preprocessing import load_and_prepare_data, split_and_scale, select_top_features

# 📂 Path to your dataset
data_path = "../data/synth_rare_event_data.csv"
target_col = "rare_event"

# 🧼 Load and prepare
X, y = load_and_prepare_data(data_path, target_col)
X_train_scaled, X_test_scaled, y_train, y_test = split_and_scale(X, y)
X_train, X_test, _ = select_top_features(X_train_scaled, y_train, X_test_scaled, return_features=True)

# %%
# 📊 Define resampling strategies
resamplers = {
    "Manual Upsampling": lambda: manual_upsampling(X_train, y_train, target_col),
    "SMOTE": lambda: smote(X_train, y_train),
    "ADASYN": lambda: adasyn(X_train, y_train),
    "Borderline SMOTE": lambda: borderline_smote(X_train, y_train),
    "SMOTETomek": lambda: smote_tomek(X_train, y_train),
    "SMOTEENN": lambda: smote_enn(X_train, y_train),
    "Random Undersample": lambda: random_undersample(X_train, y_train),
    "Cluster Centroids": lambda: cluster_centroids(X_train, y_train),
    "No Resampling": lambda: (X_train, y_train)
}

# %%
import random
from sklearn.linear_model import LogisticRegression
import numpy as np
from model_eval import evaluate_model
import matplotlib.pyplot as plt

# 🔧 Helper: mutate hyperparameters
def mutate_params(base_params, noise=0.1):
    return {
        "C": max(0.01, base_params["C"] + np.random.uniform(-noise, noise)),
        "l1_ratio": min(1.0, max(0.0, base_params["l1_ratio"] + np.random.uniform(-noise, noise)))
    }

# 🛠️ Helper: make logistic model
def make_child_model(params):
    return LogisticRegression(
        penalty='elasticnet',
        solver='saga',
        l1_ratio=params["l1_ratio"],
        C=params["C"],
        max_iter=2000,
        tol=1e-4,
        class_weight='balanced',
        random_state=42
    )

# 🎙️ Commentary templates
child_comments = [
    "throws their gloves into the arena!", "marches in with fire!", "joins the fray!",
    "is ready to make waves!", "steps into the light!"
]
survivor_comments = [
    "clutches their spot for next round.", "barely makes the cut.",
    "dominates the leaderboard.", "hangs on by a thread.", "secures their legacy."
]
winner_comments = [
    "A new legend is born!", "The crowd goes wild!",
    "Undisputed champion!", "What a run!", "Glory secured!"
]
knockout_comments = [
    "is eliminated from the arena.", "falls short this time.", "can’t continue to the next round.",
    "is knocked out!", "is out of the tournament!"
]

# 🧬 Battle + Breeding Engine
def breed_and_battle(resampled_datasets, X_test, y_test, generations=3, top_k=3, debug=True):
    population = []

    if debug:
        print(f"\n🎬 Initial Fighters Enter the Arena!")

    for label, (X_res, y_res) in resampled_datasets.items():
        base_params = {"C": 1.0, "l1_ratio": 0.5}
        model = make_child_model(base_params)
        model.fit(X_res, y_res)
        score = evaluate_model(model, X_test, y_test, label=label, return_scores=True)
        population.append({
            "model": model,
            "params": base_params,
            "score": score,
            "label": label,
            "generation": 0,
            "lineage": f"origin of {label}"
        })

    for gen in range(1, generations + 1):
        if debug: print(f"\n🎮 Generation {gen} Begins!\n" + "-" * 25)

        sorted_pop = sorted(population, key=lambda x: x["score"]["pr_auc"], reverse=True)
        top_models = sorted_pop[:top_k]

        if debug:
            print("🏆 Top Performers:")
            for i, contender in enumerate(top_models, 1):
                print(f"{i}. {contender['label']}_G{contender['generation']}: PR AUC = {contender['score']['pr_auc']:.3f}")

        new_generation = []
        for parent in top_models:
            if debug: print(f"\n💘 {parent['label']} breeds 2 children")

            for child_num in range(1, 3):
                child_params = mutate_params(parent["params"])
                child_model = make_child_model(child_params)
                X_res, y_res = resampled_datasets[parent["label"]]
                child_model.fit(X_res, y_res)
                name = f"{parent['label']}_child_{child_num}_G{gen}"
                lineage = f"child of {parent['label']}_G{parent['generation']}"
                score = evaluate_model(child_model, X_test, y_test, label=name, return_scores=True)

                if debug:
                    print(f"\n👊 {name} {random.choice(child_comments)}")
                    print(f"📍 Style: {parent['label']}")
                    print(f"🧬 Genome: C = {child_params['C']:.2f}, l1_ratio = {child_params['l1_ratio']:.2f}")
                    print(f"🔁 Generation: {gen}")
                    print(f"🏆 Last Score: PR AUC = {score['pr_auc']:.3f}")
                    print(f"🧬 Lineage: {lineage}")

                new_generation.append({
                    "model": child_model,
                    "params": child_params,
                    "score": score,
                    "label": parent["label"],
                    "generation": gen,
                    "lineage": lineage
                })

        population.extend(new_generation)

        if debug:
            survivors = sorted(population, key=lambda x: x["score"]["pr_auc"], reverse=True)[:top_k * 3]
            survivor_ids = {id(s) for s in survivors}

            print(f"\n✅ Survivors advancing to next generation:")
            for s in survivors:
                comment = random.choice(survivor_comments)
                print(f"- {s['label']}_G{s['generation']} | PR AUC = {s['score']['pr_auc']:.3f} → {comment}")

            newly_created = [m for m in population if m["generation"] == gen]
            eliminated = [m for m in newly_created if id(m) not in survivor_ids]

            if eliminated:
                print(f"\n💀 Eliminated this round:")
                for elim in eliminated:
                    print(f"- {elim['label']}_G{elim['generation']} | PR AUC = {elim['score']['pr_auc']:.3f} → {random.choice(knockout_comments)}")

    final_winner = max(population, key=lambda x: x["score"]["pr_auc"])
    print("\n🏆 GRAND CHAMPION 🏆")
    print(f"👑 Name: {final_winner['label']}_G{final_winner['generation']}")
    print(f"🔁 Generation: {final_winner['generation']}")
    print(f"🧬 Genome: C = {final_winner['params']['C']:.2f}, l1_ratio = {final_winner['params']['l1_ratio']:.2f}")
    print(f"📈 PR AUC: {final_winner['score']['pr_auc']:.3f}")
    print(f"🎖 ROC AUC: {final_winner['score']['roc_auc']:.3f}")
    print(f"🧬 Lineage: {final_winner.get('lineage', 'Origin Unknown')}")
    print(f"🏁 {random.choice(winner_comments)}")

    return population

# %%
resampled_datasets = {
    name: fn() for name, fn in resamplers.items()
}

population = breed_and_battle(
    resampled_datasets=resampled_datasets,
    X_test=X_test,
    y_test=y_test,
    generations=200,
    top_k=3,
    debug=True  # Set to False to suppress commentary
)
# Out:
# 🎬 Initial Fighters Enter the Arena!
# /Users/sophiaboettcher/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 🎮 Generation 1 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G0: PR AUC = 0.043
# 2. Manual Upsampling_G0: PR AUC = 0.035
# 3. Random Undersample_G0: PR AUC = 0.032
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G1 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.57
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 👊 Cluster Centroids_child_2_G1 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.59
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 💘 Manual Upsampling breeds 2 children
#
# 👊 Manual Upsampling_child_1_G1 is ready to make waves!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 1.09, l1_ratio = 0.58
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.035
# 🧬 Lineage: child of Manual Upsampling_G0
#
# 👊 Manual Upsampling_child_2_G1 steps into the light!
# 📍 Style: Manual Upsampling
# 🧬 Genome: C = 0.92, l1_ratio = 0.53
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.035
# 🧬 Lineage: child of Manual Upsampling_G0
#
# 💘 Random Undersample breeds 2 children
#
# 👊 Random Undersample_child_1_G1 is ready to make waves!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.07, l1_ratio = 0.48
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.031
# 🧬 Lineage: child of Random Undersample_G0
#
# 👊 Random Undersample_child_2_G1 marches in with fire!
# 📍 Style: Random Undersample
# 🧬 Genome: C = 1.10, l1_ratio = 0.41
# 🔁 Generation: 1
# 🏆 Last Score: PR AUC = 0.031
# 🧬 Lineage: child of Random Undersample_G0
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G0 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G1 | PR AUC = 0.040 → barely makes the cut.
# - Cluster Centroids_G1 | PR AUC = 0.040 → dominates the leaderboard.
# - Manual Upsampling_G0 | PR AUC = 0.035 → dominates the leaderboard.
# - Manual Upsampling_G1 | PR AUC = 0.035 → secures their legacy.
# - Manual Upsampling_G1 | PR AUC = 0.035 → dominates the leaderboard.
# - Random Undersample_G0 | PR AUC = 0.032 → hangs on by a thread.
# - Random Undersample_G1 | PR AUC = 0.031 → dominates the leaderboard.
# - Random Undersample_G1 | PR AUC = 0.031 → clutches their spot for next round.
#
# 🎮 Generation 2 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G0: PR AUC = 0.043
# 2. Cluster Centroids_G1: PR AUC = 0.040
# 3. Cluster Centroids_G1: PR AUC = 0.040
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G2 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.99, l1_ratio = 0.46
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 👊 Cluster Centroids_child_2_G2 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.55
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G2 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.06, l1_ratio = 0.58
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G1
#
# 👊 Cluster Centroids_child_2_G2 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.50
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G1
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G2 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.59
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G1
#
# 👊 Cluster Centroids_child_2_G2 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.51
# 🔁 Generation: 2
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G1
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G0 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G2 | PR AUC = 0.042 → dominates the leaderboard.
# - Cluster Centroids_G2 | PR AUC = 0.042 → clutches their spot for next round.
# - Cluster Centroids_G1 | PR AUC = 0.040 → hangs on by a thread.
# - Cluster Centroids_G2 | PR AUC = 0.040 → hangs on by a thread.
# - Cluster Centroids_G2 | PR AUC = 0.040 → clutches their spot for next round.
# - Cluster Centroids_G1 | PR AUC = 0.040 → barely makes the cut.
# - Cluster Centroids_G2 | PR AUC = 0.040 → barely makes the cut.
# - Cluster Centroids_G2 | PR AUC = 0.040 → dominates the leaderboard.
#
# 🎮 Generation 3 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G0: PR AUC = 0.043
# 2. Cluster Centroids_G2: PR AUC = 0.042
# 3. Cluster Centroids_G2: PR AUC = 0.042
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G3 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.58
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 👊 Cluster Centroids_child_2_G3 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.55
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G3 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.11, l1_ratio = 0.54
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G2
#
# 👊 Cluster Centroids_child_2_G3 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.51
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G2
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G3 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.39
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G2
#
# 👊 Cluster Centroids_child_2_G3 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.99, l1_ratio = 0.54
# 🔁 Generation: 3
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G2
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G3 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G0 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G3 | PR AUC = 0.042 → clutches their spot for next round.
# - Cluster Centroids_G2 | PR AUC = 0.042 → hangs on by a thread.
# - Cluster Centroids_G2 | PR AUC = 0.042 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.042 → clutches their spot for next round.
# - Cluster Centroids_G3 | PR AUC = 0.040 → barely makes the cut.
# - Cluster Centroids_G1 | PR AUC = 0.040 → secures their legacy.
# - Cluster Centroids_G2 | PR AUC = 0.040 → dominates the leaderboard.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G3 | PR AUC = 0.039 → falls short this time.
# - Cluster Centroids_G3 | PR AUC = 0.040 → falls short this time.
#
# 🎮 Generation 4 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G3: PR AUC = 0.043
# 2. Cluster Centroids_G0: PR AUC = 0.043
# 3. Cluster Centroids_G3: PR AUC = 0.042
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G4 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.09, l1_ratio = 0.55
# 🔁 Generation: 4
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G4 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.97, l1_ratio = 0.54
# 🔁 Generation: 4
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G4 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.56
# 🔁 Generation: 4
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 👊 Cluster Centroids_child_2_G4 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.07, l1_ratio = 0.57
# 🔁 Generation: 4
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G4 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.21, l1_ratio = 0.49
# 🔁 Generation: 4
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G4 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.11, l1_ratio = 0.60
# 🔁 Generation: 4
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G3 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G0 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G4 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G3 | PR AUC = 0.042 → secures their legacy.
# - Cluster Centroids_G2 | PR AUC = 0.042 → clutches their spot for next round.
# - Cluster Centroids_G4 | PR AUC = 0.042 → barely makes the cut.
# - Cluster Centroids_G2 | PR AUC = 0.042 → clutches their spot for next round.
# - Cluster Centroids_G3 | PR AUC = 0.042 → dominates the leaderboard.
# - Cluster Centroids_G4 | PR AUC = 0.040 → clutches their spot for next round.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G4 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G4 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G4 | PR AUC = 0.040 → can’t continue to the next round.
#
# 🎮 Generation 5 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G3: PR AUC = 0.043
# 2. Cluster Centroids_G0: PR AUC = 0.043
# 3. Cluster Centroids_G4: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G5 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.53
# 🔁 Generation: 5
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G5 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.44
# 🔁 Generation: 5
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G5 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.51
# 🔁 Generation: 5
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 👊 Cluster Centroids_child_2_G5 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.49
# 🔁 Generation: 5
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G5 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.09, l1_ratio = 0.64
# 🔁 Generation: 5
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G4
#
# 👊 Cluster Centroids_child_2_G5 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.50
# 🔁 Generation: 5
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G4
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G0 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G5 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G4 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.042 → secures their legacy.
# - Cluster Centroids_G2 | PR AUC = 0.042 → hangs on by a thread.
# - Cluster Centroids_G4 | PR AUC = 0.042 → dominates the leaderboard.
# - Cluster Centroids_G5 | PR AUC = 0.042 → hangs on by a thread.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G5 | PR AUC = 0.039 → can’t continue to the next round.
# - Cluster Centroids_G5 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G5 | PR AUC = 0.042 → is eliminated from the arena.
#
# 🎮 Generation 6 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G0: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G6 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.53
# 🔁 Generation: 6
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G6 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.88, l1_ratio = 0.45
# 🔁 Generation: 6
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G6 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.60
# 🔁 Generation: 6
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G6 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.06, l1_ratio = 0.46
# 🔁 Generation: 6
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G6 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.49
# 🔁 Generation: 6
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G0
#
# 👊 Cluster Centroids_child_2_G6 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.10, l1_ratio = 0.40
# 🔁 Generation: 6
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G0
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G3 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G6 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G6 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G0 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G5 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G4 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.042 → barely makes the cut.
# - Cluster Centroids_G2 | PR AUC = 0.042 → clutches their spot for next round.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G6 | PR AUC = 0.039 → falls short this time.
# - Cluster Centroids_G6 | PR AUC = 0.039 → is out of the tournament!
# - Cluster Centroids_G6 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G6 | PR AUC = 0.042 → can’t continue to the next round.
#
# 🎮 Generation 7 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G6: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G7 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.99, l1_ratio = 0.53
# 🔁 Generation: 7
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G7 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.40
# 🔁 Generation: 7
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G7 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.51
# 🔁 Generation: 7
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G7 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.95, l1_ratio = 0.49
# 🔁 Generation: 7
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G7 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.86, l1_ratio = 0.39
# 🔁 Generation: 7
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G6
#
# 👊 Cluster Centroids_child_2_G7 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.49
# 🔁 Generation: 7
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G6
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G6 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G7 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G6 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G0 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G4 | PR AUC = 0.043 → hangs on by a thread.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G7 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G7 | PR AUC = 0.042 → falls short this time.
# - Cluster Centroids_G7 | PR AUC = 0.042 → is out of the tournament!
# - Cluster Centroids_G7 | PR AUC = 0.040 → can’t continue to the next round.
#
# 🎮 Generation 8 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G8 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.51
# 🔁 Generation: 8
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G8 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.50
# 🔁 Generation: 8
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G8 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.06, l1_ratio = 0.44
# 🔁 Generation: 8
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G8 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.43
# 🔁 Generation: 8
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G8 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.02, l1_ratio = 0.54
# 🔁 Generation: 8
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G8 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.98, l1_ratio = 0.58
# 🔁 Generation: 8
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G3 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G7 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G6 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G6 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G0 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G4 | PR AUC = 0.043 → dominates the leaderboard.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G8 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G8 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G8 | PR AUC = 0.042 → is eliminated from the arena.
# - Cluster Centroids_G8 | PR AUC = 0.042 → is knocked out!
# - Cluster Centroids_G8 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G8 | PR AUC = 0.040 → is knocked out!
#
# 🎮 Generation 9 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G9 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.94, l1_ratio = 0.49
# 🔁 Generation: 9
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G9 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.43
# 🔁 Generation: 9
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G9 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.50
# 🔁 Generation: 9
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G9 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.97, l1_ratio = 0.57
# 🔁 Generation: 9
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G9 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.05, l1_ratio = 0.50
# 🔁 Generation: 9
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G9 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.88, l1_ratio = 0.58
# 🔁 Generation: 9
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G3 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G7 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G6 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G9 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G6 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G0 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G5 | PR AUC = 0.043 → clutches their spot for next round.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G9 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G9 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G9 | PR AUC = 0.039 → is eliminated from the arena.
# - Cluster Centroids_G9 | PR AUC = 0.042 → can’t continue to the next round.
# - Cluster Centroids_G9 | PR AUC = 0.039 → is knocked out!
#
# 🎮 Generation 10 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G10 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.51
# 🔁 Generation: 10
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G10 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.42
# 🔁 Generation: 10
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G10 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.61
# 🔁 Generation: 10
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G10 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.58
# 🔁 Generation: 10
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G10 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.57
# 🔁 Generation: 10
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G10 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.43
# 🔁 Generation: 10
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G3 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G7 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G6 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G9 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G6 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G10 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G0 | PR AUC = 0.043 → hangs on by a thread.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G10 | PR AUC = 0.041 → can’t continue to the next round.
# - Cluster Centroids_G10 | PR AUC = 0.042 → can’t continue to the next round.
# - Cluster Centroids_G10 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G10 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G10 | PR AUC = 0.039 → is eliminated from the arena.
#
# 🎮 Generation 11 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G11 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.51
# 🔁 Generation: 11
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G11 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.51
# 🔁 Generation: 11
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G11 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.06, l1_ratio = 0.55
# 🔁 Generation: 11
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G11 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.57
# 🔁 Generation: 11
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G11 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.89, l1_ratio = 0.41
# 🔁 Generation: 11
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G11 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.39
# 🔁 Generation: 11
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G3 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G7 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G11 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G11 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G6 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G9 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G7 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G6 | PR AUC = 0.043 → secures their legacy.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G11 | PR AUC = 0.041 → is out of the tournament!
# - Cluster Centroids_G11 | PR AUC = 0.039 → is out of the tournament!
# - Cluster Centroids_G11 | PR AUC = 0.042 → falls short this time.
# - Cluster Centroids_G11 | PR AUC = 0.042 → can’t continue to the next round.
#
# 🎮 Generation 12 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G12 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.86, l1_ratio = 0.45
# 🔁 Generation: 12
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G12 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.50
# 🔁 Generation: 12
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G12 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.44
# 🔁 Generation: 12
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G12 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.58
# 🔁 Generation: 12
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G12 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.87, l1_ratio = 0.55
# 🔁 Generation: 12
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G12 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.05, l1_ratio = 0.56
# 🔁 Generation: 12
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G3 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G7 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G11 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G11 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G6 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G9 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G12 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G7 | PR AUC = 0.043 → clutches their spot for next round.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G12 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G12 | PR AUC = 0.042 → is out of the tournament!
# - Cluster Centroids_G12 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G12 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G12 | PR AUC = 0.040 → is eliminated from the arena.
#
# 🎮 Generation 13 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G13 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.87, l1_ratio = 0.58
# 🔁 Generation: 13
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G13 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.51
# 🔁 Generation: 13
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G13 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.59
# 🔁 Generation: 13
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G13 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.09, l1_ratio = 0.58
# 🔁 Generation: 13
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G13 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.56
# 🔁 Generation: 13
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G13 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.44
# 🔁 Generation: 13
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G3 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G11 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G11 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G6 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G9 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G12 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G13 | PR AUC = 0.039 → falls short this time.
# - Cluster Centroids_G13 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G13 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G13 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G13 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G13 | PR AUC = 0.042 → can’t continue to the next round.
#
# 🎮 Generation 14 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G14 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.88, l1_ratio = 0.56
# 🔁 Generation: 14
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G14 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.59
# 🔁 Generation: 14
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G14 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.98, l1_ratio = 0.51
# 🔁 Generation: 14
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G14 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.58
# 🔁 Generation: 14
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G14 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.39
# 🔁 Generation: 14
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G14 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.48
# 🔁 Generation: 14
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G3 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G14 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G11 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G11 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G6 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G9 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G12 | PR AUC = 0.043 → barely makes the cut.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G14 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G14 | PR AUC = 0.039 → is out of the tournament!
# - Cluster Centroids_G14 | PR AUC = 0.041 → falls short this time.
# - Cluster Centroids_G14 | PR AUC = 0.042 → is out of the tournament!
# - Cluster Centroids_G14 | PR AUC = 0.040 → is eliminated from the arena.
#
# 🎮 Generation 15 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G15 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.57
# 🔁 Generation: 15
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G15 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.06, l1_ratio = 0.51
# 🔁 Generation: 15
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G15 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.52
# 🔁 Generation: 15
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G15 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.02, l1_ratio = 0.60
# 🔁 Generation: 15
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G15 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.48
# 🔁 Generation: 15
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G15 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.02, l1_ratio = 0.43
# 🔁 Generation: 15
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G7 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G14 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G11 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G11 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G6 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G9 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G12 | PR AUC = 0.043 → secures their legacy.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G15 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G15 | PR AUC = 0.042 → is eliminated from the arena.
# - Cluster Centroids_G15 | PR AUC = 0.043 → is knocked out!
# - Cluster Centroids_G15 | PR AUC = 0.039 → falls short this time.
# - Cluster Centroids_G15 | PR AUC = 0.042 → can’t continue to the next round.
# - Cluster Centroids_G15 | PR AUC = 0.043 → is knocked out!
#
# 🎮 Generation 16 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G16 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.02, l1_ratio = 0.41
# 🔁 Generation: 16
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G16 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.52
# 🔁 Generation: 16
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G16 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.07, l1_ratio = 0.55
# 🔁 Generation: 16
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G16 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.58
# 🔁 Generation: 16
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G16 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.58
# 🔁 Generation: 16
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G16 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.45
# 🔁 Generation: 16
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G3 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G7 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G16 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G14 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G11 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G11 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G6 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G9 | PR AUC = 0.043 → dominates the leaderboard.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G16 | PR AUC = 0.042 → is out of the tournament!
# - Cluster Centroids_G16 | PR AUC = 0.039 → is eliminated from the arena.
# - Cluster Centroids_G16 | PR AUC = 0.039 → is eliminated from the arena.
# - Cluster Centroids_G16 | PR AUC = 0.039 → can’t continue to the next round.
# - Cluster Centroids_G16 | PR AUC = 0.042 → is knocked out!
#
# 🎮 Generation 17 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G17 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.89, l1_ratio = 0.43
# 🔁 Generation: 17
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G17 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.51
# 🔁 Generation: 17
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G17 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.53
# 🔁 Generation: 17
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G17 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.59
# 🔁 Generation: 17
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G17 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.86, l1_ratio = 0.52
# 🔁 Generation: 17
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G17 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.92, l1_ratio = 0.43
# 🔁 Generation: 17
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G16 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G14 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G11 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G11 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G6 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G9 | PR AUC = 0.043 → secures their legacy.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G17 | PR AUC = 0.042 → is out of the tournament!
# - Cluster Centroids_G17 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G17 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G17 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G17 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G17 | PR AUC = 0.042 → falls short this time.
#
# 🎮 Generation 18 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G18 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.59
# 🔁 Generation: 18
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G18 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.94, l1_ratio = 0.45
# 🔁 Generation: 18
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G18 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.44
# 🔁 Generation: 18
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G18 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.51
# 🔁 Generation: 18
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G18 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.42
# 🔁 Generation: 18
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G18 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.47
# 🔁 Generation: 18
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G16 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G14 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G11 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G11 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G6 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G18 | PR AUC = 0.043 → secures their legacy.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G18 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G18 | PR AUC = 0.042 → falls short this time.
# - Cluster Centroids_G18 | PR AUC = 0.043 → is eliminated from the arena.
# - Cluster Centroids_G18 | PR AUC = 0.043 → is eliminated from the arena.
# - Cluster Centroids_G18 | PR AUC = 0.042 → is knocked out!
#
# 🎮 Generation 19 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# 3. Cluster Centroids_G7: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G19 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.54
# 🔁 Generation: 19
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G19 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.98, l1_ratio = 0.52
# 🔁 Generation: 19
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G19 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.56
# 🔁 Generation: 19
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 👊 Cluster Centroids_child_2_G19 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.09, l1_ratio = 0.54
# 🔁 Generation: 19
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G3
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G19 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.53
# 🔁 Generation: 19
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G7
#
# 👊 Cluster Centroids_child_2_G19 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.45
# 🔁 Generation: 19
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G7
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G3 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G16 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G14 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G11 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G19 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G11 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G6 | PR AUC = 0.043 → barely makes the cut.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G19 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G19 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G19 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G19 | PR AUC = 0.043 → is out of the tournament!
# - Cluster Centroids_G19 | PR AUC = 0.043 → is out of the tournament!
#
# 🎮 Generation 20 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G3: PR AUC = 0.043
# ...
# 2. Cluster Centroids_G41: PR AUC = 0.043
# 3. Cluster Centroids_G77: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G195 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.95, l1_ratio = 0.52
# 🔁 Generation: 195
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G195 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.48
# 🔁 Generation: 195
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G195 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.55
# 🔁 Generation: 195
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 👊 Cluster Centroids_child_2_G195 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.05, l1_ratio = 0.47
# 🔁 Generation: 195
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G195 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.48
# 🔁 Generation: 195
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G77
#
# 👊 Cluster Centroids_child_2_G195 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.91, l1_ratio = 0.47
# 🔁 Generation: 195
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G77
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G41 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G77 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G96 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G53 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G94 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G3 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G7 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G23 | PR AUC = 0.043 → barely makes the cut.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G195 | PR AUC = 0.040 → is knocked out!
# - Cluster Centroids_G195 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G195 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G195 | PR AUC = 0.043 → is out of the tournament!
# - Cluster Centroids_G195 | PR AUC = 0.042 → is knocked out!
# - Cluster Centroids_G195 | PR AUC = 0.043 → is eliminated from the arena.
#
# 🎮 Generation 196 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G41: PR AUC = 0.043
# 3. Cluster Centroids_G77: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G196 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.54
# 🔁 Generation: 196
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G196 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.49
# 🔁 Generation: 196
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G196 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.94, l1_ratio = 0.55
# 🔁 Generation: 196
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 👊 Cluster Centroids_child_2_G196 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.44
# 🔁 Generation: 196
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G196 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.46
# 🔁 Generation: 196
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G77
#
# 👊 Cluster Centroids_child_2_G196 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.86, l1_ratio = 0.42
# 🔁 Generation: 196
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G77
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G41 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G77 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G96 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G53 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G94 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G3 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G7 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G23 | PR AUC = 0.043 → hangs on by a thread.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G196 | PR AUC = 0.040 → falls short this time.
# - Cluster Centroids_G196 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G196 | PR AUC = 0.039 → is knocked out!
# - Cluster Centroids_G196 | PR AUC = 0.042 → can’t continue to the next round.
# - Cluster Centroids_G196 | PR AUC = 0.043 → is eliminated from the arena.
# - Cluster Centroids_G196 | PR AUC = 0.042 → is knocked out!
#
# 🎮 Generation 197 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G41: PR AUC = 0.043
# 3. Cluster Centroids_G77: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G197 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.88, l1_ratio = 0.54
# 🔁 Generation: 197
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G197 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.89, l1_ratio = 0.45
# 🔁 Generation: 197
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G197 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.86, l1_ratio = 0.49
# 🔁 Generation: 197
# 🏆 Last Score: PR AUC = 0.039
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 👊 Cluster Centroids_child_2_G197 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.88, l1_ratio = 0.54
# 🔁 Generation: 197
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G197 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.04, l1_ratio = 0.48
# 🔁 Generation: 197
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G77
#
# 👊 Cluster Centroids_child_2_G197 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.57
# 🔁 Generation: 197
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G77
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G41 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G77 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G96 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G53 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G94 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G3 | PR AUC = 0.043 → clutches their spot for next round.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G23 | PR AUC = 0.043 → barely makes the cut.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G197 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G197 | PR AUC = 0.043 → is eliminated from the arena.
# - Cluster Centroids_G197 | PR AUC = 0.039 → is eliminated from the arena.
# - Cluster Centroids_G197 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G197 | PR AUC = 0.042 → falls short this time.
# - Cluster Centroids_G197 | PR AUC = 0.040 → is eliminated from the arena.
#
# 🎮 Generation 198 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G41: PR AUC = 0.043
# 3. Cluster Centroids_G77: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G198 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.95, l1_ratio = 0.58
# 🔁 Generation: 198
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G198 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.93, l1_ratio = 0.43
# 🔁 Generation: 198
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G198 is ready to make waves!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.53
# 🔁 Generation: 198
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 👊 Cluster Centroids_child_2_G198 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.00, l1_ratio = 0.56
# 🔁 Generation: 198
# 🏆 Last Score: PR AUC = 0.041
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G198 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.88, l1_ratio = 0.55
# 🔁 Generation: 198
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G77
#
# 👊 Cluster Centroids_child_2_G198 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.86, l1_ratio = 0.41
# 🔁 Generation: 198
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G77
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G41 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G77 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G96 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G53 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G94 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G3 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G23 | PR AUC = 0.043 → barely makes the cut.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G198 | PR AUC = 0.040 → is eliminated from the arena.
# - Cluster Centroids_G198 | PR AUC = 0.042 → falls short this time.
# - Cluster Centroids_G198 | PR AUC = 0.043 → falls short this time.
# - Cluster Centroids_G198 | PR AUC = 0.041 → can’t continue to the next round.
# - Cluster Centroids_G198 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G198 | PR AUC = 0.042 → is eliminated from the arena.
#
# 🎮 Generation 199 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G41: PR AUC = 0.043
# 3. Cluster Centroids_G77: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G199 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.95, l1_ratio = 0.53
# 🔁 Generation: 199
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G199 throws their gloves into the arena!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.98, l1_ratio = 0.58
# 🔁 Generation: 199
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G199 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.94, l1_ratio = 0.47
# 🔁 Generation: 199
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 👊 Cluster Centroids_child_2_G199 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.96, l1_ratio = 0.45
# 🔁 Generation: 199
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G199 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.39
# 🔁 Generation: 199
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G77
#
# 👊 Cluster Centroids_child_2_G199 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.02, l1_ratio = 0.50
# 🔁 Generation: 199
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G77
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G41 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G77 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G96 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G53 | PR AUC = 0.043 → dominates the leaderboard.
# - Cluster Centroids_G94 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G3 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G7 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G23 | PR AUC = 0.043 → hangs on by a thread.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G199 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G199 | PR AUC = 0.040 → can’t continue to the next round.
# - Cluster Centroids_G199 | PR AUC = 0.043 → can’t continue to the next round.
# - Cluster Centroids_G199 | PR AUC = 0.042 → is eliminated from the arena.
# - Cluster Centroids_G199 | PR AUC = 0.042 → is eliminated from the arena.
# - Cluster Centroids_G199 | PR AUC = 0.043 → is eliminated from the arena.
#
# 🎮 Generation 200 Begins!
# -------------------------
# 🏆 Top Performers:
# 1. Cluster Centroids_G5: PR AUC = 0.043
# 2. Cluster Centroids_G41: PR AUC = 0.043
# 3. Cluster Centroids_G77: PR AUC = 0.043
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G200 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.05, l1_ratio = 0.45
# 🔁 Generation: 200
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 👊 Cluster Centroids_child_2_G200 joins the fray!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 0.90, l1_ratio = 0.44
# 🔁 Generation: 200
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G5
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G200 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.03, l1_ratio = 0.44
# 🔁 Generation: 200
# 🏆 Last Score: PR AUC = 0.043
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 👊 Cluster Centroids_child_2_G200 marches in with fire!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.05, l1_ratio = 0.40
# 🔁 Generation: 200
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G41
#
# 💘 Cluster Centroids breeds 2 children
#
# 👊 Cluster Centroids_child_1_G200 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.01, l1_ratio = 0.55
# 🔁 Generation: 200
# 🏆 Last Score: PR AUC = 0.040
# 🧬 Lineage: child of Cluster Centroids_G77
#
# 👊 Cluster Centroids_child_2_G200 steps into the light!
# 📍 Style: Cluster Centroids
# 🧬 Genome: C = 1.02, l1_ratio = 0.46
# 🔁 Generation: 200
# 🏆 Last Score: PR AUC = 0.042
# 🧬 Lineage: child of Cluster Centroids_G77
#
# ✅ Survivors advancing to next generation:
# - Cluster Centroids_G5 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G41 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G77 | PR AUC = 0.043 → barely makes the cut.
# - Cluster Centroids_G96 | PR AUC = 0.043 → secures their legacy.
# - Cluster Centroids_G53 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G94 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G3 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G7 | PR AUC = 0.043 → hangs on by a thread.
# - Cluster Centroids_G23 | PR AUC = 0.043 → dominates the leaderboard.
#
# 💀 Eliminated this round:
# - Cluster Centroids_G200 | PR AUC = 0.043 → falls short this time.
# - Cluster Centroids_G200 | PR AUC = 0.042 → falls short this time.
# - Cluster Centroids_G200 | PR AUC = 0.043 → falls short this time.
# - Cluster Centroids_G200 | PR AUC = 0.042 → can’t continue to the next round.
# - Cluster Centroids_G200 | PR AUC = 0.040 → is out of the tournament!
# - Cluster Centroids_G200 | PR AUC = 0.042 → is out of the tournament!
#
# 🏆 GRAND CHAMPION 🏆
# 👑 Name: Cluster Centroids_G5
# 🔁 Generation: 5
# 🧬 Genome: C = 0.96, l1_ratio = 0.49
# 📈 PR AUC: 0.043
# 🎖 ROC AUC: 0.639
# 🧬 Lineage: child of Cluster Centroids_G0
# 🏁 Glory secured!

# %%
# 🏁 Final Round Summary

# Sort population by PR AUC
final_results = sorted(population, key=lambda x: x["score"]["pr_auc"], reverse=True)

champion = final_results[0]

print("\n🏆 GRAND CHAMPION 🏆")
print(f"👑 Name: {champion['label']}")
print(f"🔁 Generation: {champion['generation']}")
print(f"🧬 Genome: C = {champion['params']['C']:.2f}, l1_ratio = {champion['params']['l1_ratio']:.2f}")
print(f"📈 PR AUC: {champion['score']['pr_auc']:.3f}")
print(f"🎖 ROC AUC: {champion['score']['roc_auc']:.3f}")
print(f"🧬 Lineage: {champion.get('lineage', 'Origin Unknown')}")
# Out:
# 🏆 GRAND CHAMPION 🏆
# 👑 Name: Cluster Centroids
# 🔁 Generation: 5
# 🧬 Genome: C = 0.96, l1_ratio = 0.49
# 📈 PR AUC: 0.043
# 🎖 ROC AUC: 0.639
# 🧬 Lineage: child of Cluster Centroids_G0

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# podium_df = pd.DataFrame([
#     {
#         "Name": f"{entry['label']} (Gen {entry['generation']})",
#         "PR AUC": entry["score"]["pr_auc"]
#     }
#     for entry in final_results[:3]
# ])

# podium_df = podium_df[::-1]  # So the best is on top visually

# plt.figure(figsize=(8, 4))
# bars = plt.barh(podium_df["Name"], podium_df["PR AUC"], color=["#cd7f32", "#c0c0c0", "#ffd700"])
# plt.title("Top 3 Models: Battle Royale Final Standings")
# plt.xlabel("PR AUC")
# plt.grid(True)
# plt.show()

# %%
import pandas as pd

tracking_df = pd.DataFrame([
    {
        "Generation": model["generation"],
        "Strategy": model["label"],
        "PR AUC": model["score"]["pr_auc"],
        "ROC AUC": model["score"]["roc_auc"]
    }
    for model in population
])

plt.figure(figsize=(10, 6))
for strat in tracking_df["Strategy"].unique():
    group = tracking_df[tracking_df["Strategy"] == strat]
    plt.plot(group["Generation"], group["PR AUC"], marker="o", label=strat)

plt.title("PR AUC Evolution Over Generations")
plt.xlabel("Generation")
plt.ylabel("PR AUC")
plt.grid(True)
plt.legend(loc="lower right", bbox_to_anchor=(1.0, 0))
plt.tight_layout()
plt.show()
